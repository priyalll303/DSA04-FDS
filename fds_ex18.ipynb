# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df = pd.read_csv(r"C:\Users\rjana\OneDrive\Downloads\Documents\Desktop\program\fundaments of DS\labfds\hospital_data.csv")

# %%
print("Mean:\n", df.mean())
print("Median:\n", df.median())
print("Std Dev:\n", df.std())
# Out:
# Mean:
#  age    40.60
# fat    23.24
# dtype: float64
# Median:
#  age    39.00
# fat    22.75
# dtype: float64
# Std Dev:
#  age    11.758685
# fat     3.542190
# dtype: float64

# %%
# Boxplots
df[['age', 'fat']].plot(kind='box')
plt.title("Boxplot for Age and %Fat")
plt.show()

# %%
# Scatter
sns.scatterplot(x='age', y='fat', data=df)
plt.title("Age vs %Fat")
plt.show()
